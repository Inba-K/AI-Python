# %% [markdown]
# <a href="https://colab.research.google.com/github/Inba-K/AI-Python/blob/main/CarAnalytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-e8346614-5b2c-4e90-b5af-261a7f774d24" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e8346614-5b2c-4e90-b5af-261a7f774d24">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv("CarAnalytics.csv")

# %%
df
# Out:
#      Car_ID          Brand    Model  Year  Engine_Size  Horsepower  Torque  \
# 0         1         Toyota    Camry  2019          1.8         127     189
# 1         2          Honda    Civic  2020          2.1         134     198
# 2         3           Ford    Focus  2021          2.4         141     207
# 3         4            BMW     330i  2022          2.7         148     216
# 4         5           Audi       A4  2023          3.0         155     225
# ..      ...            ...      ...   ...          ...         ...     ...
# 196     197        Hyundai  Elantra  2023          3.0         356     269
# 197     198            Kia       K5  2024          3.3         363     278
# 198     199  Mercedes-Benz  C-Class  2025          3.6         370     287
# 199     200         Nissan   Altima  2018          3.9         377     296
# 200     201   Aston Martin      DB9  2020          7.4         800     640
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_ID         201 non-null    int64
#  1   Brand          201 non-null    object
#  2   Model          201 non-null    object
#  3   Year           201 non-null    int64
#  4   Engine_Size    201 non-null    float64
#  5   Horsepower     201 non-null    int64
#  6   Torque         201 non-null    int64
#  7   Transmission   201 non-null    object
#  8   Fuel_Type      201 non-null    object
#  9   Mileage        201 non-null    int64
#  10  Price          201 non-null    int64
#  11  Resale_Value   201 non-null    float64
#  12  Safety_Rating  201 non-null    int64
#  13  Color          201 non-null    object
#  14  Country        201 non-null    object
#  15  Sales          201 non-null    int64
#  16  CO2_Emission   201 non-null    int64
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df=df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_ID         201 non-null    int64
#  1   Brand          201 non-null    object
#  2   Model          201 non-null    object
#  3   Year           201 non-null    int64
#  4   Engine_Size    201 non-null    float64
#  5   Horsepower     201 non-null    int64
#  6   Torque         201 non-null    int64
#  7   Transmission   201 non-null    object
#  8   Fuel_Type      201 non-null    object
#  9   Mileage        201 non-null    int64
#  10  Price          201 non-null    int64
#  11  Resale_Value   201 non-null    float64
#  12  Safety_Rating  201 non-null    int64
#  13  Color          201 non-null    object
#  14  Country        201 non-null    object
#  15  Sales          201 non-null    int64
#  16  CO2_Emission   201 non-null    int64
# ...

# %%
df['Acceleration']=df['Acceleration'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_ID         201 non-null    int64
#  1   Brand          201 non-null    object
#  2   Model          201 non-null    object
#  3   Year           201 non-null    int64
#  4   Engine_Size    201 non-null    float64
#  5   Horsepower     201 non-null    int64
#  6   Torque         201 non-null    int64
#  7   Transmission   201 non-null    object
#  8   Fuel_Type      201 non-null    object
#  9   Mileage        201 non-null    int64
#  10  Price          201 non-null    int64
#  11  Resale_Value   201 non-null    float64
#  12  Safety_Rating  201 non-null    int64
#  13  Color          201 non-null    object
#  14  Country        201 non-null    object
#  15  Sales          201 non-null    int64
#  16  CO2_Emission   201 non-null    int64
# ...

# %%
plt.figure(figsize=(12,5))
plt.bar(df['Brand'],df['Sales'],color='green',width=0.8)
plt.xlabel("Brand")
plt.ylabel("Sales")
plt.title("Sales for each brand")
# Out:
# Text(0.5, 1.0, 'Sales for each brand')

# %%
plt.hist(df['Price'],color='blue')
# Out:
# (array([93., 90., 17.,  0.,  0.,  0.,  0.,  0.,  0.,  1.]),
#  array([ 22007. ,  43818.7,  65630.4,  87442.1, 109253.8, 131065.5,
#         152877.2, 174688.9, 196500.6, 218312.3, 240124. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.boxplot(x='Fuel_Type',y='Horsepower',data=df)
# Out:
# <Axes: xlabel='Fuel_Type', ylabel='Horsepower'>

# %%
plt.scatter(df['Horsepower'],df['Price'],marker='*',color='red')

# %%
plt.scatter(df['Mileage'],df['CO2_Emission'],marker='^',color='green')

# %%
plt.plot(df['Year'],df['Price'])

# %%
df1=df[['Car_ID','Year','Engine_Size','Horsepower','Torque','Mileage','Price','Resale_Value','Safety_Rating','Sales','CO2_Emission','Acceleration','Top_Speed']]
corr=df1.corr()
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
sns.countplot(x='Sales',hue='Price',data=df)
# Out:
# <Axes: xlabel='Sales', ylabel='count'>

# %%
df2=df[['Horsepower','Price','Mileage','Engine_Size','Top_Speed','Brand']]
sns.pairplot(df2,hue='Brand')
